# %% [markdown]
# Binary neurons ($x_1, x_2 \in \{ 0 , 1 \}^2$) with controllable stimulus-dependent upstream inputs $f_1(s),f_2(s)$ and tunable noise correlations $\omega$:
# $$P(x | s) \propto \exp (f_1(s)x_1 + f_2(s)x_2 + \omega x_1x_2)$$
#
# Control the properties of the tuning functions (width, gain, and distance between centers). You can also control the total avg. firing (i.e. how many spikes you get per sample on average). Notice the effects on the output fields (marginal statistics) and one the mutual information between population firing and stimuli!
#
# INSTRUCTIONS: simply execute the cell below (Shift + Enter, or press "Run" $\triangleright$, takes a few sec) and play with the sliders!

# %%
# %pip install ipympl
# %pip install scipy
# %matplotlib widget
exec(open("./libr/2cell_MI_fixAvg.py").read())
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
