# %% [markdown]
# Binary neurons ($x_1, x_2 \in \{ 0 , 1 \}^2$) with controllable stimulus-dependent upstream inputs $f_1(s),f_2(s)$ and tunable noise correlations $\omega$:
# $$P(x | s) \propto \exp (f_1(s)x_1 + f_2(s)x_2 + \omega x_1x_2)$$
# Marginal statistics are fix; with the slider, vary $\omega$ and automatically see the appropriate input functions. Also notice the effect on the mutual information (MI)!
#
# INSTRUCTIONS: simply execute the cell below (Shift + Enter, or press "Run" $\triangleright$), wait a few sec and play with the slider

# %%
# %pip install ipympl
# %pip install scipy
# %matplotlib widget
# initial parameters for marginal statistics (tuning functions)
width = 5
bias = -0.5
gain = 2
dist = 3
# execute the main script
exec(open("./libr/2cell_covariab_libr.py").read())
# Out:
# libr/2cell_covariab_libr.py:123: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
